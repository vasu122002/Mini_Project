# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('file_version_5')

# %%
data.sample(50)
# Out:
#       Unnamed: 0.1  Unnamed: 0                            property_name  \
# 817            819         819         3 BHK Flat in Sector 109 Gurgaon
# 1335          1343        1343                2 BHK Flat in Palam Vihar
# 2791          2806        2806          3 BHK Flat in Sector 71 Gurgaon
# 589            591         591          3 BHK Flat in Sector 92 Gurgaon
# 931            933         933         4 BHK Flat in Sector 104 Gurgaon
# 36              36          36         3 BHK Flat in Sector 109 Gurgaon
# 652            654         654          4 BHK Flat in Sector 22 Gurgaon
# 2417          2429        2429          2 BHK Flat in Sector 82 Gurgaon
# 2347          2359        2359          1 BHK Flat in Sector 36 Gurgaon
# 2777          2792        2792                    3 BHK Flat in Bhondsi
# 2153          2164        2164                 3 BHK Flat in New Colony
# 1267          1269        1269         2 BHK Flat in Sector 70A Gurgaon
# ...

# %%
x = 2035/0.9
x
# Out:
# 2261.111111111111

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1              0
# Unnamed: 0                0
# property_name             0
# society                   1
# price                     1
# price_per_sqft            1
# bedRoom                   0
# bathroom                  0
# balcony                   0
# additionalRoom            0
# floorNum                  0
# facing                  872
# agePossession             0
# super_built_up_area    1048
# built_up_area          2042
# carpet_area            1175
# study room                0
# pooja room                0
# store room                0
# others                    0
# servant room              0
# furnished_type            0
# sector                    0
# dtype: int64

# %%
data.drop(index = 18 , inplace = True )

# %%
data[data['price'].isnull()].index
# Out:
# Index([], dtype='int64')

# %%
plt.scatter(data['super_built_up_area'] ,data['carpet_area'])

# %%
all_present_df = data[~((data['super_built_up_area'].isnull()) | (data['built_up_area'].isnull()) | (data['carpet_area'].isnull()))]

# %%
all_present_df
# Out:
#       Unnamed: 0.1  Unnamed: 0                     property_name  \
# 38              38          38  2 BHK Flat in Sector 37C Gurgaon
# 103            104         104   3 BHK Flat in Sector 77 Gurgaon
# 133            135         135   3 BHK Flat in Sector 78 Gurgaon
# 136            138         138   2 BHK Flat in Sector 79 Gurgaon
# 141            143         143  3 BHK Flat in Sector 12A Gurgaon
# ...            ...         ...                               ...
# 2906          2921        2921  2 BHK Flat in Sector 99A Gurgaon
# 2921          2936        2936    2 BHK Flat in Sector 3 Gurgaon
# 2923          2938        2938       2 BHK Flat in Dharam Colony
# 2963          2978        2978   2 BHK Flat in Sector 79 Gurgaon
# 2972          2987        2987         1 BHK Flat in Palam Vihar
#
#                     society  price  price_per_sqft  bedRoom  bathroom  \
# 38               ild greens   0.78          5714.0        2         2
# ...

# %%
#  checking the columns where the supewr_built_up area is present and the carpet_area is also presents but the built_up_area is not presents ,so filling the null values with help of these two columns values.
sbc_df = data[~(data['super_built_up_area'].isnull()) & (data['built_up_area'].isnull()) & ~(data['carpet_area'].isnull())]

# %%
sbc_df
# Out:
#       Unnamed: 0.1  Unnamed: 0                         property_name  \
# 31              31          31       4 BHK Flat in Sector 43 Gurgaon
# 36              36          36      3 BHK Flat in Sector 109 Gurgaon
# 37              37          37                   2 BHK Flat in Sohna
# 59              59          59  2 BHK Flat in Sector-7 Housing Board
# 60              60          60                   2 BHK Flat in Sohna
# ...            ...         ...                                   ...
# 2940          2955        2955       2 BHK Flat in Sector 90 Gurgaon
# 2955          2970        2970      2 BHK Flat in Sector 99A Gurgaon
# 2956          2971        2971       3 BHK Flat in Sector 79 Gurgaon
# 2957          2972        2972      3 BHK Flat in Sector 103 Gurgaon
# 2965          2980        2980       3 BHK Flat in Sector 78 Gurgaon
#
#                                  society  price  price_per_sqft  bedRoom  \
# ...

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14984\1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
data.update(sbc_df)

# %%
# sb null c is present built up null
c_df = data[(data['super_built_up_area'].isnull()) & (data['built_up_area'].isnull()) & ~(data['carpet_area'].isnull())]

# %%
c_df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 7                7           7
# ...            ...         ...
# 2958          2973        2973
# 2962          2977        2977
# 2966          2981        2981
# 2967          2982        2982
# 2975          2990        2990
#
#                                         property_name  \
# 0                        2 BHK Flat in Krishna Colony
# 1                           2 BHK Flat in Ashok Vihar
# 2                                 2 BHK Flat in Sohna
# 3                     2 BHK Flat in Sector 61 Gurgaon
# 7                    3 BHK Flat in Sector 104 Gurgaon
# ...                                               ...
# 2958                        4 BHK Flat in DLF Phase 4
# 2962                      3 BHK Flat in Rajendra Park
# 2966                 3 BHK Flat in Sector 88A Gurgaon
# ...

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14984\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
data.update(c_df)

# %%
# sb present c is null built up null
s_df = data[~(data['super_built_up_area'].isnull()) & (data['built_up_area'].isnull()) & (data['carpet_area'].isnull())]

# %%
s_df
# Out:
#       Unnamed: 0.1  Unnamed: 0                            property_name  \
# 4                4           4          2 BHK Flat in Sector 92 Gurgaon
# 6                6           6  3 BHK Flat in Dwarka Expressway Gurgaon
# 13              13          13          2 BHK Flat in Sector 33 Gurgaon
# 14              14          14          2 BHK Flat in Sector 90 Gurgaon
# 19              19          19            3 BHK Flat in Sector-33 Sohna
# ...            ...         ...                                      ...
# 2973          2988        2988         3 BHK Flat in Sector 107 Gurgaon
# 2974          2989        2989              3 BHK Flat in Dharam Colony
# 2977          2992        2992          3 BHK Flat in Sector 86 Gurgaon
# 2979          2994        2994         3 BHK Flat in Sector 108 Gurgaon
# 2981          2996        2996          4 BHK Flat in Sector 54 Gurgaon
#
#                          society  price  price_per_sqft  bedRoom  bathroom  \
# ...

# %%
s_df['built_up_area'].fillna(round(s_df['super_built_up_area']-s_df['super_built_up_area']*10/100),inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14984\3444369663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s_df['built_up_area'].fillna(round(s_df['super_built_up_area']-s_df['super_built_up_area']*10/100),inplace=True)

# %%
data.update(s_df)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1              0
# Unnamed: 0                0
# property_name             0
# society                   1
# price                     0
# price_per_sqft            0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# additionalRoom            0
# floorNum                  0
# facing                  872
# agePossession             0
# super_built_up_area    1047
# built_up_area             0
# carpet_area            1175
# study room                0
# pooja room                0
# store room                0
# others                    0
# servant room              0
# furnished_type            0
# sector                    0
# dtype: int64

# %%
pd.set_option('display.max_columns' , None)

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0                     property_name  \
# 0                0           0      2 BHK Flat in Krishna Colony
# 1                1           1         2 BHK Flat in Ashok Vihar
# 2                2           2               2 BHK Flat in Sohna
# 3                3           3   2 BHK Flat in Sector 61 Gurgaon
# 4                4           4   2 BHK Flat in Sector 92 Gurgaon
# ...            ...         ...                               ...
# 2977          2992        2992   3 BHK Flat in Sector 86 Gurgaon
# 2978          2993        2993   5 BHK Flat in Sector 48 Gurgaon
# 2979          2994        2994  3 BHK Flat in Sector 108 Gurgaon
# 2980          2995        2995         3 BHK Flat in DLF Phase 3
# 2981          2996        2996   4 BHK Flat in Sector 54 Gurgaon
#
#                      society  price  price_per_sqft  bedRoom  bathroom  \
# 0     maa bhagwati residency   0.45          5000.0        2         2
# ...

# %%
a_df  = data[(data['agePossession'] == 'undefined') & (data['price'] <1)]

# %%
a_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, property_name, society, price, price_per_sqft, bedRoom, bathroom, balcony, additionalRoom, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, pooja room, store room, others, servant room, furnished_type, sector]
# Index: []

# %%
a_df['agePossession'] = 'old_property'
a_df['agePossession']
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14984\1949228069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a_df['agePossession'] = 'old_property'
# 5       old_property
# 13      old_property
# 25      old_property
# 117     old_property
# 150     old_property
# 1954    old_property
# 2028    old_property
# 2079    old_property
# 2221    old_property
# 2254    old_property
# 2255    old_property
# 2296    old_property
# 2338    old_property
# 2383    old_property
# 2503    old_property
# 2618    old_property
# 2729    old_property
# 2813    old_property
# Name: agePossession, dtype: object

# %%
data.update(a_df)

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'undefined':
        mode_value = data[(data['sector'] == row['sector']) & (data['property_name'] == row['property_name'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
data['agePossession'] = data.apply(mode_based_imputation,axis=1)

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'undefined':
        mode_value = data[(data['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            print(mode_value)
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
data['agePossession'].value_counts()
# Out:
# agePossession
# new_property    2437
# old_property     544
# Name: count, dtype: int64

# %%
data['agePossession'].isnull().sum()
# Out:
# 0

# %%
data[data['agePossession'] == 'undefined']
# Out:
#       Unnamed: 0.1  Unnamed: 0                     property_name  \
# 3                3           3   2 BHK Flat in Sector 61 Gurgaon
# 5                5           5   2 BHK Flat in Sector 36 Gurgaon
# 13              13          13   2 BHK Flat in Sector 33 Gurgaon
# 25              25          25   2 BHK Flat in Sector 36 Gurgaon
# 29              29          29    2 BHK Flat in Sector 3 Gurgaon
# ...            ...         ...                               ...
# 2843          2858        2858    2 BHK Flat in Sector 3 Gurgaon
# 2848          2863        2863   3 BHK Flat in Sector 59 Gurgaon
# 2881          2896        2896  2 BHK Flat in Sector 63A Gurgaon
# 2899          2914        2914     3 BHK Flat in Sector-33 Sohna
# 2920          2935        2935   1 BHK Flat in Sector 40 Gurgaon
#
#                              society  price  price_per_sqft  bedRoom  \
# 3                smart world orchard   1.47         12250.0        2
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'property_name', 'society', 'price',
#        'price_per_sqft', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'floorNum', 'facing', 'agePossession', 'super_built_up_area',
#        'built_up_area', 'carpet_area', 'study room', 'pooja room',
#        'store room', 'others', 'servant room', 'furnished_type', 'sector'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0.1','Unnamed: 0','facing','super_built_up_area','carpet_area'] , inplace = True , axis =1)

# %%
data.to_csv('file_version_6')
