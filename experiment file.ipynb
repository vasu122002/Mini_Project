# %%
# !pip install pandas-profiling

# %%
import pandas as pd

# %%
data = pd.read_csv('cleaned_flats_version2')

# %%
pd.set_option('display.max_columns' , None)

# %%
data.head(5)
# Out:
#    Unnamed: 0  index                    property_name                 society  \
# 0           0      0     2 BHK Flat in Krishna Colony  maa bhagwati residency
# 1           1      1        2 BHK Flat in Ashok Vihar            apna enclave
# 2           2      2              2 BHK Flat in Sohna  tulsiani easy in homes
# 3           3      3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard
# 4           4      4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend
#
#    price  price_per_sqft                            areaWithType  bedRoom  \
# 0   0.45          5000.0          Carpet area: 900 (83.61 sq.m.)        2
# 1   0.50          7692.0          Carpet area: 650 (60.39 sq.m.)        2
# 2   0.40          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3   1.47         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4   0.70          5204.0  Super Built up area 1345(124.95 sq.m.)        2
#
# ...

# %%
data.drop(['areaWithType' , 'address' , 'nearbyLocations' ,'description' ,'furnishDetails' , 'features' ,'rating' ] , inplace = True , axis = 1)

# %%
data.drop(columns = 'index' , inplace = True , axis = 1)

# %%
import re

# %%
for i in ['BHK','Flat' ,'in' ,'Gurgaon',',' , " "]:
    data['sector'] = data['sector'].str.replace(i , "" ,regex = False)

# %%
re.sub(r"\s+", "", data['sector'][0])
# Out:
# '2KrishnaColony'

# %%
l1 = []
for i in range(2997):
    l1.append(data['sector'][i][1:])

# %%
data['sector'] = l1

# %%
data['sector'].value_counts()
# Out:
# sector
# Sohna                 159
# Sector102             113
# Sector85              110
# Sector92              100
# Sector69               92
#                      ...
# GolfCourseRoad          1
# nearsector1market       1
# Sector-5Sohna           1
# FaridabadRoad           1
# GodrejAriasector79      1
# Name: count, Length: 185, dtype: int64

# %%
data.drop('Unnamed: 0' , inplace = True , axis = 1)

# %%
data.to_csv('file_version_4')
